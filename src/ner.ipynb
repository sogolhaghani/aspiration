# %%
from transformers import AutoTokenizer,AutoModelForTokenClassification
from transformers import pipeline


# tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
# print('OK')
# # sentences = [list of sentences]
# # inputs = tokenizer(sentences, padding="max_length", truncation=True)

model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")
print('OK')


# nlp = pipeline("ner", model=model, tokenizer=tokenizer)
# example = "My name is Wolfgang and I live in Berlin"

# ner_results = nlp(example)
# print(ner_results)

# %%
import spacy
from spacy import displacy

nlp = spacy.load('en_core_web_sm')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_10133/189219165.py in <module>
#       1 import spacy
#       2 from spacy import displacy
# ----> 3 from spacy_grammar.grammar import Grammar
#       4 nlp = spacy.load('en_core_web_sm')
#
# ModuleNotFoundError: No module named 'spacy_grammar'

# %%
# doc = nlp("Reactive and proactive needs.")
# doc = nlp("246–248 Buss, Plomin, and, 288–292 Cattell and, 264, 266–271 deﬁnition of, 7 Eysenck and, 278–282 McCrae, Costa, and, 282–288 overview of, 239–240, 292–293 Triadic reciprocality, 417 Twin studies, 282, 283, 288–289, 290–292, 444 Type A/Type B behavior, 258 Tyranny of the shoulds, 169, 176 Unconditional positive regard, 330, 332 collective, 109–110 inﬂuence of, 479 personal, 108 S. Freud and, 56, 57, 76–77 Unique traits, 266 Urethral stage, 191 Utopian society, 389 Validity, 12, 13–14 Values, personal, 255–256 reinforcement schedules, 381–383 Verbal modeling, 403 Vicarious reinforcement, 400 Video games and aggressive behavior, Virtual identity, 227 Virtual research method, 30 Von Franz, Marie-Louise, 117 Watson, John B., 5–6, 371–372, 377 Wolff, Toni, 184 Womb envy, 170–171 Freud’s view of, 69, 84, 92 Horney’s view of, 159, 170–173 midlife crisis in, 123–124 Word association, 19, 117–118 Wundt, Wilhelm, 5 Young adulthood, 216–217 Youngest child, 141–142 Zuckerman, Marvin, and sensation seeking, 437–445")
# doc = nlp("Subjective well-being, 457 Subjectivity in personality theories, Sublimation, 63 Subliminal perception, 76–77 Subsidiation, 190, 270 Successive approximation, 383 Superego, 58–59, 186–187 Superiority complex, 134 Superstitious behavior, 384–385 Surface traits, 267–268 Symptom analysis, 118 T-data, 274–275 Television and aggressive behavior, Temperament theory, 288–292 Temperament traits, 267, 268 Test anxiety, 416 Test-retest method, 13 Test standardization, 12–26 Thema, 190 Thematic Apperception Test Thought-sampling research, 20–21 Token economy program, 386–387 Trait theories Allport and,")
doc = nlp("The higher the correlation between the two sets of scores, the greater the test’s reliability.")
displacy.render(doc, style="dep")
# for ent in doc.ents:
#     print(ent.text, ent.start_char, ent.end_char, ent.label_)


for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.is_alpha, token.is_stop)   
# _has_verb = False
# for token in doc:
#     if token.pos_ == 'VERB':
#         _has_verb = True    
# print(_has_verb)         

# print("- - - - - -")
# for token in doc:
#     print(token.text,token.dep_, token.head.text, token.head.pos_,
#             [child for child in token.children])    
# doc = nlp("Freud’s views had an impact not only on psychology but also on the general culture.")        
# for chunk in doc.noun_chunks:
#     print(chunk.text, chunk.root.text, chunk.root.dep_,chunk.root.head.text)  
# print("- - - - - -")
# doc = nlp("He succeeded in redeﬁning the human personality and revolutionizing our ways of thinking about human nature.") 
# for chunk in doc.noun_chunks:
#     print(chunk.text, chunk.root.text, chunk.root.dep_,chunk.root.head.text)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="27cde765e4164beb9a75543f252a3c0a-0" class="displacy" width="2850" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">higher</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">correlation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">sets</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">scores,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">greater</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">test</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">reliability.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27cde765e4164beb9a75543f252a3c0a-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27cde765e4164beb9a75543f252a3c0a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27cde765e4164beb9a75543f252a3c0a-0-1" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27cde765e4164beb9a75543f252a3c0a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27cde765e4164beb9a75543f252a3c0a-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27cde765e4164beb9a75543f252a3c0a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27cde765e4164beb9a75543f252a3c0a-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27cde765e4164beb9a75543f252a3c0a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27cde765e4164beb9a75543f252a3c0a-0-4" stroke-width="2px" d="M945,352.0 C945,177.0 1265.0,177.0 1265.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27cde765e4164beb9a75543f252a3c0a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,354.0 L937,342.0 953,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27cde765e4164beb9a75543f252a3c0a-0-5" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27cde765e4164beb9a75543f252a3c0a-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27cde765e4164beb9a75543f252a3c0a-0-6" stroke-width="2px" d="M770,352.0 C770,89.5 1270.0,89.5 1270.0,352.0" fill="none" stroke="currentColor"/>
#     <
# The the PRON DT advmod True True
# higher high ADJ JJR amod True False
# the the DET DT det True True
# correlation correlation NOUN NN ROOT True False
# between between ADP IN prep True True
# the the DET DT det True True
# two two NUM CD nummod True True
# sets set NOUN NNS pobj True False
# of of ADP IN prep True True
# scores score NOUN NNS pobj True False
# , , PUNCT , punct False False
# the the PRON DT advmod True True
# greater great ADJ JJR amod True False
# the the DET DT det True True
# test test NOUN NN poss True False
# ’s ’s PART POS case False True
# reliability reliability NOUN NN appos True False
# . . PUNCT . punct False False

# %%
def _extract_head(doc):
    _sub = []
    for chunk in doc.noun_chunks:
        if chunk.root.dep_ == 'nsubj':
            _sub.append(chunk.text)
    return _sub

# %%
doc = nlp("—Publishers Weekly “Wow!")
heads = _extract_head(doc)
heads
# Out:
# []
